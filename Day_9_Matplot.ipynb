# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/data_science_practice/blob/main/Day_9_Matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
company=['TCS','IBM','EY','TechM','INFY']
share=[250,300,100,80,400]

# %%
plt.pie(share,labels=company,autopct='%.2f%%',colors=['y','g','r','c','m'])
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(
#     *args: 'float | ArrayLike | str',
#     scalex: 'bool' = True,
#     scaley: 'bool' = True,
#     data=None,
#     **kwargs
# ) -> 'list[Line2D]'
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
# ...

# %%
import numpy as np

salary=np.random.randint(5000,100001,100)
salary
# Out:
# array([12326, 52364, 58094, 72562, 97697, 73820, 86920, 71596, 72578,
#        79066, 81318, 33588,  5548, 97849, 75586, 34902, 59600, 21876,
#        33110, 19716, 35935, 32889, 51516,  7668, 77395, 65889, 65957,
#        79331, 36942, 58514, 65107, 20507,  9440, 55768, 53955, 33693,
#        19078, 60586, 87626, 46132, 52571, 75139, 17654, 57251, 70290,
#        23327, 53247, 90791, 68087, 53565, 34588, 38267, 44753, 27583,
#        63888, 28129, 14823, 32742, 75376, 47732, 33007, 55489, 33019,
#        59177, 60421, 35342, 17437, 99435,  9033, 47209, 73867, 59390,
#        40748, 13506, 44133, 14626, 49057, 60935, 45316, 44610, 52271,
#         5839, 68574, 99319, 42124, 46898, 95148, 74349, 52339, 54097,
#        94666, 99891,  7467, 55320, 23266, 61181, 31859,  5159, 49444,
#        51408])

# %%
plt.hist(salary,bins=[10000,25000,30000,50000])
# Out:
# (array([12.,  2., 26.]),
#  array([10000., 25000., 30000., 50000.]),
#  <BarContainer object of 3 artists>)

# %%
data=np.random.random(100)
data
# Out:
# array([0.7932793 , 0.07327744, 0.20847109, 0.89463235, 0.26807057,
#        0.79274324, 0.2297729 , 0.8225661 , 0.79788871, 0.96116065,
#        0.19187139, 0.55294522, 0.96879024, 0.91843237, 0.30829656,
#        0.23709482, 0.68989711, 0.30454821, 0.82818934, 0.27645021,
#        0.11715788, 0.36923732, 0.37143524, 0.67363628, 0.71136169,
#        0.06509608, 0.39292468, 0.39052624, 0.48702076, 0.58719529,
#        0.94448992, 0.92324708, 0.80574032, 0.86742456, 0.32141606,
#        0.10073909, 0.1295501 , 0.51470307, 0.8768215 , 0.7086924 ,
#        0.55075762, 0.14399798, 0.80963481, 0.00546369, 0.59904529,
#        0.93486467, 0.23048908, 0.20176807, 0.46826026, 0.9657646 ,
#        0.19302172, 0.45517033, 0.84624352, 0.5638021 , 0.13917418,
#        0.08963139, 0.89847712, 0.07340957, 0.70899311, 0.76211842,
#        0.88002963, 0.96070369, 0.56738272, 0.70394357, 0.75009893,
#        0.09251602, 0.48969937, 0.59699095, 0.59686358, 0.92105399,
# ...

# %%
plt.scatter(range(100),data,marker='D',color='m')

# %%
plt.subplot(2,2,1)
plt.hist(salary,bins=[10000,25000,30000,50000])

plt.subplot(2,2,2)
plt.bar(state,record,width=0.4,color='#663873',label='Covid Count')
plt.xticks(state,['MH','GT','UP','HP'])

plt.subplot(2,2,3)
plt.pie(share,labels=company,autopct='%.f%%',colors=['y','g','r','c','m'])

plt.subplot(2,2,4)
plt.scatter(range(100),data,marker='D',color='m')

plt.savefig('state_2.jpeg',dpi=400)

# %%
state=['Maharashtra','Gujrat','Up','Himachal Pradesh']
record=[140,90,100,400]
plt.bar(state,record,width=0.4,color='#663873',label='Covid Count')
# Out:
# <BarContainer object of 4 artists>

# %%
import pandas as pd
path = "https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv"

f =  pd.read_csv(path)
f[:2]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                       5.0
# 1      Juventus   77000.0  405.0          Right                       5.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# 1          5.0       ST    2018           2022-01-01  6.166667   183.0
#
#    Release Clause
# 0        226500.0
# 1        127100.0

# %%
pf=f['Preferred Foot'].value_counts()
pf
# Out:
# Preferred Foot
# Right    13996
# Left      4211
# Name: count, dtype: int64

# %%
pf.values
# Out:
# array([13996,  4211])

# %%
pf.index
# Out:
# Index(['Right', 'Left'], dtype='object', name='Preferred Foot')

# %%
plt.pie(pf.values,labels=['Right','Left'],autopct='%.f%%')
plt.show()

# %%
plt.scatter(f['Height'],f['Weight'])
