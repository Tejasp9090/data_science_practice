# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/data_science_practice/blob/main/DS_Pandas_Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
f=pd.read_csv('fifa_eda.csv')
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
# Feteching first five records
f.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
f[:1]
# Out:
#        ID      Name  Age Nationality  Overall  Potential          Club  \
# 0  158023  L. Messi   31   Argentina       94         94  FC Barcelona
#
#       Value   Wage Preferred Foot  International Reputation  Skill Moves  \
# 0  110500.0  565.0           Left                       5.0          4.0
#
#   Position  Joined Contract Valid Until    Height  Weight  Release Clause
# 0       RF    2004           2021-01-01  5.583333   159.0        226500.0

# %%
#feteching the last three elements
f.tail(3)
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0
# ...

# %%
f[-3:]
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0
# ...

# %%
#fetch random N Records
f.sample(3)
# Out:
#            ID          Name  Age   Nationality  Overall  Potential  \
# 16929  231617     L. Davies   18       England       56         68
# 10518  204689  I. Ouédraogo   29  Burkina Faso       65         65
# 16655  241905   S. Ben Amar   20       Morocco       57         69
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 16929  Cambridge United  130.0   1.0          Right                       1.0
# 10518    SKN St. Pölten  550.0   5.0          Right                       1.0
# 16655   Nîmes Olympique  190.0   2.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 16929          2.0       RB    2015           2019-01-01  5.916667   154.0
# 10518          2.0       ST    2018           2020-01-01  5.833333   172.0
# 16655          2.0       ST    2018           2021-01-01  6.083333   168.0
#
#        Release Clause
# 16929           254.0
# 10518           798.0
# ...

# %% [markdown]
# **To select rows and columns we have 2 options**
# 1)loc:label Based selection
# 2)iloc:index based selection

# %%
f.loc[:5,:]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
# 5              Chelsea   93000.0  340.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# ...

# %%
f.loc[:5,'Name':'Nationality']
# Out:
#                 Name  Age Nationality
# 0           L. Messi   31   Argentina
# 1  Cristiano Ronaldo   33    Portugal
# 2          Neymar Jr   26      Brazil
# 3             De Gea   27       Spain
# 4       K. De Bruyne   27     Belgium
# 5          E. Hazard   27     Belgium

# %%
f.loc[:10:1,'Name':'Nationality':2]
# Out:
#                  Name Nationality
# 0            L. Messi   Argentina
# 1   Cristiano Ronaldo    Portugal
# 2           Neymar Jr      Brazil
# 3              De Gea       Spain
# 4        K. De Bruyne     Belgium
# 5           E. Hazard     Belgium
# 6           L. Modrić     Croatia
# 7           L. Suárez     Uruguay
# 8        Sergio Ramos       Spain
# 9            J. Oblak    Slovenia
# 10     R. Lewandowski      Poland

# %%
f.loc[50:55:2,'ID':'Overall':2]
# Out:
#         ID  Age  Overall
# 50  175943   31       87
# 52  171877   30       87
# 54  152729   31       87

# %%
f.loc[50:55:2,['Club','Age','Name']]
# Out:
#             Club  Age        Name
# 50        Napoli   31  D. Mertens
# 52        Napoli   30   M. Hamšík
# 54  FC Barcelona   31       Piqué
